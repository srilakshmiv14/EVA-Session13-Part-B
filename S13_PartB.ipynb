# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P4', major=6, minor=1, total_memory=7611MB, multi_processor_count=20)

# %%
ls
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# drive/  gdrive/  sample_data/

# %%
cd gdrive/My Drive/EVA4/YoloV3
# Out:
# /content/gdrive/My Drive/EVA4/YoloV3

# %%
# !ls
# Out:
# data  __pycache__  test.py  train.py  weights

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# 2020-04-24 13:38:03.157501: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (506 found, 0 missing, 1 empty, 0 duplicate, for 507 images): 100% 507/507 [00:00<00:00, 970.94it/s]
# Caching images (0.3GB): 100% 507/507 [03:20<00:00,  2.53it/s]
# Reading image shapes: 100% 507/507 [00:00<00:00, 1006.18it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# 2020-04-24 13:46:29.316340: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (506 found, 0 missing, 1 empty, 0 duplicate, for 507 images): 100% 507/507 [00:00<00:00, 993.19it/s]
# Caching images (0.3GB): 100% 507/507 [00:02<00:00, 242.78it/s]
# ...

# %%
# !python detect.py --source Chota_Bheem.mp4 --conf-thres 0.2 --output output
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.2, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='Chota_Bheem.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/749) Chota_Bheem.mp4: 448x512 Done. (0.038s)
# video 1/1 (2/749) Chota_Bheem.mp4: 448x512 Done. (0.034s)
# video 1/1 (3/749) Chota_Bheem.mp4: 448x512 Done. (0.034s)
# video 1/1 (4/749) Chota_Bheem.mp4: 448x512 Done. (0.034s)
# video 1/1 (5/749) Chota_Bheem.mp4: 448x512 Done. (0.034s)
# video 1/1 (6/749) Chota_Bheem.mp4: 448x512 Done. (0.032s)
# video 1/1 (7/749) Chota_Bheem.mp4: 448x512 Done. (0.033s)
# video 1/1 (8/749) Chota_Bheem.mp4: 448x512 Done. (0.032s)
# ...

# %%
# !python detect.py --source Corona_Virus_Chota_Bheem.mp4 --conf-thres 0.2 --output output1
# Out:
# python3: can't open file 'detect.py': [Errno 107] Transport endpoint is not connected

# %% [markdown]
# Submitted by G Uday Kiran and V Srilakshmi
